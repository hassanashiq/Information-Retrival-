# %% [markdown]
# # Semester Project : Information Retrieval System
#  ### NUST
# - #### Submitted by : Hassan Ashiq BESE 23 C
# - ###### Link to my GitHub Repository <a href="https://github.com/hassanashiqasse/PCA">Click Here</a>

# %% [markdown]
# ### Importing Libraries

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from collections import Counter
from num2words import num2words

import nltk
import os
import string
import numpy as np
import copy
import pandas as pd
import pickle
import re
import math

# %% [markdown]
# ### Reading CISI.ALL File

# %%
with open('IR Project/CISI.ALL') as CISI_file:
    lines = ""
    for l in CISI_file.readlines():
        lines += "\n" + l.strip() if l.startswith(".") else " " + l.strip()
    lines = lines.lstrip("\n").split("\n")
    
    
print("Done")
# Out:
# Done

# %% [markdown]
# ### Placing each document in CISI File in a dictionary

# %%
doc_set = {}
doc_id = ""
doc_text = ""
for l in lines:
    if l.startswith(".I"):
        doc_id = l.split(" ")[1].strip()
    elif l.startswith(".X"):
        doc_set[doc_id] = doc_text.lstrip(" ")
        doc_id = ""
        doc_text = ""
    else:
        doc_text += l.strip()[3:] + " " # The first 3 characters of a line can be ignored.

# Print something to see the dictionary structure, etc.
print(f"Number of documents = {len(doc_set)}" + ".\n")
# Out:
# Number of documents = 1460.

# %%
doc_set["3"]
# Out:
# "Two Kinds of Power An Essay on Bibliographic Control Wilson, P. The relationships between the organization and control of writings and the organization and control of knowledge and information will inevitably enter our story, for writings contain, along with much else, a great deal of mankind's stock of knowledge and information.  Bibliographical control is a form of power, and if knowledge itself is a form of power, as the familiar slogan claims, bibliographical control is in a certain sense power over power, power to obtain the knowledge recorded in written form.  As writings are not simply, and not in any simple way, storehouses of knowledge, we cannot satisfactorily discuss bibliographical control as simply control over the knowledge and information contained in writings. "

# %% [markdown]
# ### Reading CISI Query File and placing each query in a dictionary

# %%
with open('IR Project/datasets.QRY') as f:
    lines = ""
    for l in f.readlines():
        lines += "\n" + l.strip() if l.startswith(".") else " " + l.strip()
    lines = lines.lstrip("\n").split("\n")
    
qry_set = {}
qry_id = ""
for l in lines:
    if l.startswith(".I"):
        qry_id = l.split(" ")[1].strip()
    elif l.startswith(".W"):
        qry_set[qry_id] = l.strip()[3:]
        qry_id = ""
    
# Print something to see the dictionary structure, etc.
print(f"Number of queries = {len(qry_set)}" + ".\n")
print("Query # 2 : ", qry_set["2"]) # note that the dictionary indexes are strings, not numbers.
# Out:
# Number of queries = 112.
#
# Query # 2 :  How can actually pertinent data, as opposed to references or entire articles themselves, be retrieved automatically in response to information requests?

# %%
qry_set["1"]
# Out:
# 'What problems and concerns are there in making up descriptive titles? What difficulties are involved in automatically retrieving articles from approximate titles? What is the usual relevance of the content of articles to their titles?'

# %% [markdown]
# ### Pre Process of Data

# %%
def convert_lower_case(data):
    return np.char.lower(data)

# %%
def remove_stop_words(data):
    stop_words = stopwords.words('english')
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if w not in stop_words and len(w) > 1:
            new_text = new_text + " " + w
    return new_text

# %%
def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], ' ')
        data = np.char.replace(data, "  ", " ")
    data = np.char.replace(data, ',', '')
    return data

# %%
def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

# %%
def stemming(data):
    stemmer= PorterStemmer()
    
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + stemmer.stem(w)
    return new_text

# %%
def convert_numbers(data):
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        try:
            w = num2words(int(w))
        except:
            a = 0
        new_text = new_text + " " + w
    new_text = np.char.replace(new_text, "-", " ")
    return new_text

# %%
def preprocess(data):
    data = convert_lower_case(data)
    data = remove_punctuation(data) #remove comma seperately
    data = remove_apostrophe(data)
    data = remove_stop_words(data)
    #data = convert_numbers(data)
    data = stemming(data)
    data = remove_punctuation(data)
    #data = convert_numbers(data)
    data = stemming(data) #needed again as we need to stem the words
    data = remove_punctuation(data) #needed again as num2word is giving few hypens and commas fourty-one
    data = remove_stop_words(data) #needed again as num2word is giving stop words 101 - one hundred and one
    return data

# %%
processed_set={}
proc_token_id=""
proc_token_text=""

for i in doc_set:
    doc_token_id=i
    processed_set[doc_token_id]=preprocess(doc_set[str(i)])
print("done")
# Out:
# done

# %%
doc_set["2"]
# Out:
# 'Use Made of Technical Libraries Slater, M. This report is an analysis of 6300 acts of use in 104 technical libraries in the United Kingdom. Library use is only one aspect of the wider pattern of information use.  Information transfer in libraries is restricted to the use of documents.  It takes no account of documents used outside the library, still less of information transferred orally from person to person.  The library acts as a channel in only a proportion of the situations in which information is transferred. Taking technical information transfer as a whole, there is no doubt that this proportion is not the major one.  There are users of technical information - particularly in technology rather than science - who visit libraries rarely if at all, relying on desk collections of handbooks, current periodicals and personal contact with their colleagues and with people in other organizations.  Even regular library users also receive information in other ways. '

# %%
processed_set["2"]
# Out:
# ' use made technic librari slater report analysi 6300 act use 104 technic librari unit kingdom librari use one aspect wider pattern inform use inform transfer librari restrict use document take account document use outsid librari still less inform transfer oral person person librari act channel proport situat inform transfer take technic inform transfer whole doubt proport major one user technic inform particularli technolog rather scienc visit librari rare reli desk collect handbook current period person contact colleagu peopl organ even regular librari user also receiv inform way'

# %% [markdown]
# #### Converting prcessed text to tokens and placing in a dictionary where keys are the docs id

# %%
tokens_set={}
doc_token_id=""
doct_token_text=""

for i in processed_set:
    doc_token_id=i
    tokens_set[doc_token_id]=word_tokenize(processed_set[str(i)])
print("done")
# Out:
# done

# %%
np.array(tokens_set["2"]).T
# Out:
# array(['use', 'made', 'technic', 'librari', 'slater', 'report', 'analysi',
#        '6300', 'act', 'use', '104', 'technic', 'librari', 'unit',
#        'kingdom', 'librari', 'use', 'one', 'aspect', 'wider', 'pattern',
#        'inform', 'use', 'inform', 'transfer', 'librari', 'restrict',
#        'use', 'document', 'take', 'account', 'document', 'use', 'outsid',
#        'librari', 'still', 'less', 'inform', 'transfer', 'oral', 'person',
#        'person', 'librari', 'act', 'channel', 'proport', 'situat',
#        'inform', 'transfer', 'take', 'technic', 'inform', 'transfer',
#        'whole', 'doubt', 'proport', 'major', 'one', 'user', 'technic',
#        'inform', 'particularli', 'technolog', 'rather', 'scienc', 'visit',
#        'librari', 'rare', 'reli', 'desk', 'collect', 'handbook',
#        'current', 'period', 'person', 'contact', 'colleagu', 'peopl',
#        'organ', 'even', 'regular', 'librari', 'user', 'also', 'receiv',
#        'inform', 'way'], dtype='<U12')

# %% [markdown]
# #### Calculating DF

# %%
DF = {}

for i in range(len(tokens_set)):
    tokens = tokens_set[str(i+1)]
    for w in tokens:
        try:
            DF[w].add(i)
        except:
            DF[w] = {i}
for i in DF:
    DF[i] = len(DF[i])

# %%
DF
# Out:
# {'18': 9,
#  'edit': 44,
#  'dewey': 13,
#  'decim': 16,
#  'classif': 105,
#  'comaromi': 1,
#  'present': 318,
#  'studi': 362,
#  'histori': 52,
#  'first': 175,
#  'ddc': 5,
#  'publish': 122,
#  '1876': 4,
#  'eighteenth': 1,
#  '1971': 27,
#  'futur': 95,
#  'continu': 68,
#  'appear': 86,
#  'need': 251,
#  'spite': 7,
#  'long': 48,
#  'healthi': 1,
#  'life': 39,
#  'howev': 111,
#  'full': 41,
#  'stori': 4,
#  'never': 15,
#  'told': 4,
#  'biographi': 3,
#  'briefli': 34,
#  'describ': 271,
#  'system': 515,
#  'attempt': 125,
#  'provid': 251,
#  'detail': 101,
#  'work': 252,
#  'spur': 3,
#  'growth': 67,
#  'librarianship': 49,
#  'countri': 46,
#  'abroad': 5,
#  'use': 659,
#  'made': 211,
#  'technic': 130,
#  'librari': 555,
#  'slater': 5,
#  'report': 185,
#  'analysi': 226,
#  '6300': 1,
#  'act': 27,
#  '104': 1,
#  'unit': 94,
#  'kingdom': 10,
#  'one': 341,
#  'aspect': 103,
#  'wider': 17,
#  'pattern': 85,
#  'inform': 660,
#  'transfer': 30,
#  'restrict': 25,
#  'document': 251,
#  'take': 66,
#  'account': 66,
#  'outsid': 19,
#  'still': 32,
#  'less': 66,
#  'oral': 4,
#  'person': 68,
#  'channel': 19,
#  'proport': 30,
#  'situat': 64,
#  'whole': 44,
#  'doubt': 12,
#  'major': 143,
#  'user': 235,
#  'particularli': 46,
#  'technolog': 110,
#  'rather': 77,
#  'scienc': 287,
#  'visit': 8,
#  'rare': 15,
#  'reli': 8,
#  'desk': 5,
#  'collect': 189,
#  'handbook': 10,
#  'current': 150,
#  'period': 112,
#  'contact': 10,
#  'colleagu': 12,
#  'peopl': 54,
#  'organ': 171,
#  'even': 89,
#  'regular': 25,
#  'also': 204,
#  'receiv': 49,
#  'way': 141,
#  'two': 232,
#  'kind': 66,
#  'power': 31,
#  'essay': 21,
#  'bibliograph': 149,
#  'control': 91,
#  'wilson': 4,
#  'relationship': 83,
#  'write': 34,
#  'knowledg': 101,
#  'inevit': 11,
#  'enter': 14,
#  'contain': 67,
#  'along': 29,
#  'much': 84,
#  'el': 6,
#  'great': 66,
#  'deal': 84,
#  'mankind': 4,
#  'stock': 12,
#  'form': 164,
#  'familiar': 15,
#  'slogan': 1,
#  'claim': 21,
#  'certain': 82,
#  'sen': 40,
#  'obtain': 94,
#  'record': 98,
#  'written': 48,
#  'simpli': 15,
#  'simpl': 50,
#  'storeh': 2,
#  'satisfactorili': 6,
#  'discuss': 262,
#  'univ': 179,
#  'final': 60,
#  'research': 362,
#  'project': 102,
#  'buckland': 6,
#  'establish': 106,
#  'nine': 28,
#  'new': 238,
#  '1960': 17,
#  'provok': 3,
#  'highli': 40,
#  'stimul': 8,
#  'examin': 117,
#  'natur': 124,
#  'purpo': 142,
#  'manag': 96,
#  'academ': 88,
#  'attitud': 28,
#  'method': 266,
#  'question': 121,
#  'although': 58,
#  'chang': 117,
#  'basic': 130,
#  'difficulti': 35,
#  'remain': 38,
#  'lack': 28,
#  'object': 104,
#  'best': 46,
#  'servic': 267,
#  'ugc': 2,
#  'committ': 30,
#  'parri': 2,
#  'repot': 2,
#  '267': 3,
#  'gener': 330,
#  'endor': 2,
#  'stress': 19,
#  'provi': 18,
#  'game': 4,
#  'brophi': 2,
#  'profess': 100,
#  'educ': 92,
#  'becom': 91,
#  'widespread': 12,
#  'last': 57,
#  'decad': 36,
#  'number': 206,
#  'field': 193,
#  'mani': 195,
#  'hundr': 24,
#  'year': 225,
#  'origin': 82,
#  'trace': 14,
#  'war': 13,
#  'militari': 8,
#  'train': 39,
#  'real': 27,
#  'thing': 16,
#  'either': 62,
#  'unavail': 4,
#  'danger': 8,
#  'recent': 93,
#  'time': 220,
#  'sophist': 14,
#  'larg': 188,
#  'electron': 28,
#  'comput': 276,
#  'handl': 55,
#  'complex': 54,
#  'calcul': 21,
#  'involv': 80,
#  'sinc': 99,
#  '1956': 7,
#  'well': 150,
#  'develop': 378,
#  'introduc': 37,
#  'techniqu': 162,
#  'spread': 11,
#  'rapidli': 32,
#  'wide': 60,
#  'varieti': 53,
#  'disciplin': 60,
#  'today': 34,
#  'level': 72,
#  'primari': 43,
#  'school': 70,
#  'class': 51,
#  'cour': 61,
#  'experienc': 14,
#  'men': 17,
#  'women': 5,
#  'main': 59,
#  'cau': 27,
#  'explo': 13,
#  'rapid': 45,
#  'simul': 18,
#  'mathemat': 65,
#  'model': 103,
#  'possibl': 176,
#  'advanc': 69,
#  'abstract': 118,
#  'concept': 155,
#  'borko': 10,
#  'graduat': 29,
#  'includ': 168,
#  'materi': 119,
#  'characteristc': 1,
#  'type': 141,
#  'histor': 29,
#  'public': 186,
#  'industri': 86,
#  'especi': 34,
#  'state': 142,
#  'standard': 88,
#  'prepar': 75,
#  'evalu': 174,
#  'product': 107,
#  'topic': 41,
#  'call': 69,
#  'text': 88,
#  'section': 28,
#  'instruct': 23,
#  'variou': 136,
#  'supplement': 15,
#  'exampl': 103,
#  'exerci': 11,
#  'appendix': 7,
#  'brief': 21,
#  'index': 254,
#  'autom': 53,
#  'treat': 31,
#  'exten': 36,
#  'believ': 32,
#  'deserv': 6,
#  'greater': 34,
#  'emphasi': 46,
#  'past': 68,
#  'increasingli': 30,
#  'import': 153,
#  'effort': 89,
#  'expend': 9,
#  'extract': 17,
#  'student': 71,
#  'librarian': 162,
#  'abstractor': 3,
#  'benefit': 30,
#  'know': 26,
#  'understand': 58,
#  'program': 175,
#  'analyz': 94,
#  'select': 178,
#  'key': 37,
#  'sentenc': 14,
#  'segment': 12,
#  'opportun': 17,
#  'avail': 123,
#  'part': 126,
#  'volunt': 2,
#  'worker': 23,
#  'find': 115,
#  'activ': 124,
#  'pleasant': 1,
#  'reward': 16,
#  'contribut': 60,
#  'effect': 187,
#  'store': 31,
#  'chapter': 51,
#  'devot': 33,
#  'career': 13,
#  'build': 38,
#  'guid': 45,
#  'architectur': 3,
#  'issu': 50,
#  'solut': 55,
#  'ellsworth': 4,
#  'book': 295,
#  'repr': 94,
#  'success': 55,
#  'problem': 313,
#  'architect': 3,
#  'face': 34,
#  'plan': 100,
#  'colleg': 53,
#  'remodel': 1,
#  'enlarg': 4,
#  'exist': 98,
#  'structur': 173,
#  'make': 167,
#  'case': 80,
#  'done': 27,
#  'mason': 4,
#  'brown': 8,
#  'yale': 12,
#  'unsuccess': 1,
#  'except': 33,
#  'show': 97,
#  'avoid': 17,
#  'mistak': 1,
#  'identifi': 89,
#  'honor': 3,
#  'guy': 1,
#  'lyle': 4,
#  'farber': 1,
#  'staff': 50,
#  'member': 53,
#  'individu': 91,
#  'apprenticeship': 1,
#  'administr': 60,
#  'perhap': 32,
#  'signif': 95,
#  'acquir': 23,
#  'engend': 1,
#  'insist': 3,
#  'must': 90,
#  'interest': 134,
#  'content': 74,
#  'dealt': 13,
#  'love': 1,
#  'literatur': 221,
#  'respect': 58,
#  'scholarship': 8,
#  'admir': 4,
#  'good': 47,
#  'read': 45,
#  'manifest': 9,
#  'notabl': 7,
#  'admonit': 1,
#  'though': 31,
#  'primarili': 44,
#  'constantli': 7,
#  'keep': 27,
#  'mind': 22,
#  'oblig': 7,
#  'contemporari': 17,
#  'poetri': 2,
#  'fiction': 1,
#  'bell': 4,
#  'letter': 15,
#  'felt': 16,
#  'respon': 63,
#  'cross': 17,
#  'disciplinari': 7,
#  'line': 119,
#  'fell': 2,
#  'faculti': 23,
#  'mostli': 6,
#  'concern': 159,
#  'apt': 4,
#  'overlook': 7,
#  'portion': 11,
#  'substitut': 13,
#  'thorough': 9,
#  'acquaint': 5,
#  'critic': 65,
#  'review': 111,
#  'counsel': 2,
#  'presid': 5,
#  'professor': 9,
#  'thrust': 2,
#  'world': 72,
#  'impress': 6,
#  'upon': 67,
#  'us': 43,
#  'access': 80,
#  'hyman': 1,
#  'assum': 40,
#  'addit': 79,
#  'held': 20,
#  'promi': 16,
#  'analyt': 19,
#  'consid': 223,
#  'approach': 138,
#  'survey': 121,
#  'compar': 126,
#  'tradit': 55,
#  'idea': 59,
#  'direct': 66,
#  'princip': 30,
#  'data': 304,
#  'gather': 32,
#  'instrument': 20,
#  'documentari': 7,
#  'opinion': 26,
#  'questionnair': 35,
#  'follow': 102,
#  '1890': 1,
#  '1970': 32,
#  'shelf': 12,
#  'brow': 6,
#  'left': 14,
#  'unresolv': 2,
#  'evid': 39,
#  'resist': 5,
#  'exhaust': 16,
#  'confirm': 7,
#  'open': 14,
#  'rel': 89,
#  'locat': 32,
#  'meant': 5,
#  'arou': 3,
#  'intellectu': 27,
#  'social': 128,
#  'polit': 15,
#  'averag': 37,
#  'citizen': 7,
#  'affect': 48,
#  'democrat': 3,
#  'self': 24,
#  'realiz': 14,
#  'definit': 54,
#  'vari': 31,
#  'greatli': 22,
#  'indulg': 2,
#  'untutor': 1,
#  'benefici': 5,
#  'reader': 95,
#  'valuabl': 23,
#  'guidanc': 8,
#  'scholar': 16,
#  'resourc': 70,
#  'palmour': 3,
#  'recommend': 43,
#  'nation': 131,
#  'improv': 115,
#  '48': 4,
#  'percent': 26,
#  'interlibrari': 10,
#  'loan': 15,
#  'bulk': 3,
#  'satisfi': 31,
#  'photocopi': 10,
#  'rang': 42,
#  'augment': 8,
#  'request': 70,
#  'focu': 36,
#  'physic': 75,
#  'base': 286,
#  'commun': 194,
#  'design': 194,
#  'featur': 43,
#  'without': 68,
#  'initi': 43,
#  'confin': 4,
#  'depend': 46,
#  'deliveri': 10,
#  'journal': 143,
#  'articl': 131,
#  'center': 86,
#  'comprehen': 43,
#  'subject': 235,
#  'coverag': 32,
#  'exclud': 11,
#  'medicin': 29,
#  'worthwhil': 4,
#  'irrespect': 3,
#  'languag': 123,
#  'acquisit': 40,
#  'ford': 5,
#  'scope': 36,
#  'outlin': 52,
#  'introduct': 35,
#  'acknowledg': 7,
#  'polici': 46,
#  'serial': 48,
#  'kindr': 1,
#  'relat': 226,
#  'thoroughli': 7,
#  'paper': 268,
#  'cite': 46,
#  'refer': 165,
#  'note': 37,
#  'central': 44,
#  'order': 115,
#  'routin': 9,
#  'manual': 45,
#  'practic': 160,
#  'treatment': 21,
#  'particular': 113,
#  'depth': 20,
#  'modest': 10,
#  'enorm': 11,
#  '3rd': 2,
#  'clark': 2,
#  'ligu': 1,
#  'de': 11,
#  'bibliothequ': 1,
#  'europeenn': 1,
#  'recherch': 1,
#  'liber': 4,
#  'set': 115,
#  'intern': 87,
#  'non': 30,
#  'govern': 62,
#  'aim': 54,
#  'close': 40,
#  'collabor': 14,
#  'western': 9,
#  'europ': 5,
#  'help': 73,
#  'qualiti': 42,
#  'second': 60,
#  'meet': 59,
#  'assembl': 10,
#  'luxembourg': 1,
#  '1972': 17,
#  'decid': 25,
#  'hold': 38,
#  'seminar': 9,
#  'third': 37,
#  'charg': 25,
#  'would': 123,
#  'european': 7,
#  'lend': 15,
#  'feasibl': 35,
#  'centr': 10,
#  'prefer': 29,
#  'machin': 112,
#  'readabl': 39,
#  'whatev': 13,
#  'mean': 153,
#  'propo': 95,
#  'area': 126,
#  'council': 17,
#  'grant': 14,
#  'toward': 74,
#  'cost': 150,
#  'sussex': 1,
#  '17': 7,
#  '19': 6,
#  'septemb': 11,
#  '1973': 13,
#  'ad695049': 1,
#  'wooster': 1,
#  'ever': 21,
#  'pretend': 2,
#  'expert': 19,
#  'microfich': 6,
#  'nevertheless': 11,
#  'invit': 7,
#  'address': 24,
#  'annual': 33,
#  'northeastern': 1,
#  'confer': 30,
#  'waltham': 1,
#  'massachusett': 4,
#  'april': 11,
#  '1968': 37,
#  'temer': 1,
#  'like': 79,
#  'fich': 2,
#  'uniform': 9,
#  'feder': 21,
#  'cuddli': 1,
#  'revi': 22,
#  'ad': 33,
#  '669204': 1,
#  'thesi': 6,
#  'rest': 5,
#  'frequent': 38,
#  'neglect': 8,
#  'principl': 74,
#  'goe': 10,
#  'beyond': 17,
#  'commonli': 12,
#  'accept': 56,
#  'function': 108,
#  'circul': 38,
#  'storag': 84,
#  'mere': 25,
#  'hou': 16,
#  'extend': 30,
#  'teach': 27,
#  'process': 216,
#  'afford': 9,
#  'encourag': 16,
#  'better': 52,
#  'essenti': 46,
#  'tool': 59,
#  'fulli': 29,
#  'effici': 81,
#  'retain': 4,
#  'substanti': 26,
#  'independ': 32,
#  'found': 94,
#  'footnot': 5,
#  'bibliographi': 52,
#  'brought': 22,
#  'date': 40,
#  'flow': 42,
#  'laboratori': 25,
#  'allen': 6,
#  'thoma': 9,
#  'cohen': 1,
#  'stephen': 9,
#  'modifi': 15,
#  'sociometr': 4,
#  'network': 63,
#  'result': 291,
#  'interact': 61,
#  'star': 1,
#  'adopt': 37,
#  'congress': 32,
#  'matthi': 1,
#  'procedur': 105,
#  'may': 187,
#  'serv': 77,
#  'exact': 8,
#  'seri': 51,
#  'suggest': 143,
#  'step': 45,
#  'proven': 6,
#  'actual': 62,
#  'necessari': 72,
#  'criteria': 47,
#  'reclassif': 2,
#  'attent': 65,
#  'given': 157,
#  'lc': 13,
#  'law': 26,
#  'pz3': 1,
#  'pz4': 1,
#  'tabl': 34,
#  'viiia': 1,
#  'ixa': 1,
#  'throughout': 28,
#  'entir': 32,
#  'explain': 36,
#  'applic': 147,
#  'illustr': 49,
#  'mechan': 71,
#  'catalogu': 38,
#  'card': 51,
#  'copi': 26,
#  'significantli': 16,
#  'xerox': 3,
#  'oper': 203,
#  'annot': 7,
#  'judg': 28,
#  'reclassifi': 1,
#  'wish': 17,
#  'delv': 1,
#  'deepli': 3,
#  'tortuou': 1,
#  'frustrat': 4,
#  '50': 13,
#  'catalog': 109,
#  'enclo': 1,
#  'parenth': 1,
#  'sourc': 102,
#  'support': 72,
#  'argument': 15,
#  'adventur': 3,
#  'voigt': 1,
#  'scholarli': 12,
#  'fill': 15,
#  'progress': 66,
#  'obviou': 14,
#  'front': 5,
#  'caught': 1,
#  'enthusiast': 2,
#  'visual': 7,
#  'potenti': 64,
#  'certainli': 16,
#  'everi': 45,
#  'volum': 80,
#  'group': 133,
#  'demonstr': 37,
#  'implic': 46,
#  'inventori': 15,
#  'expect': 46,
#  'dedic': 3,
#  'realiti': 6,
#  'assess': 47,
#  'go': 27,
#  'fast': 8,
#  'hope': 52,
#  'get': 19,
#  'statu': 31,
#  'produc': 98,
#  'lie': 10,
#  'ahead': 3,
#  'age': 27,
#  'marc': 26,
#  'busi': 30,
#  'easier': 8,
#  'immedi': 26,
#  'file': 105,
#  'manipul': 19,
#  'defend': 2,
#  'adequ': 46,
#  'fact': 74,
#  'determin': 119,
#  'difficult': 31,
#  'widen': 4,
#  'dimen': 12,
#  'reflect': 48,
#  'name': 53,
#  'media': 25,
#  'togeth': 48,
#  'children': 4,
#  'clear': 27,
#  'rule': 57,
#  'bibliotherapi': 1,
#  'slow': 5,
#  'theori': 140,
#  'manageri': 8,
#  'come': 36,
#  'provoc': 2,
#  'controversi': 13,
#  'degr': 43,
#  'assist': 40,
#  'modern': 39,
#  'dissemin': 69,
#  'mauerhoff': 2,
#  '1974': 5,
#  'duplic': 20,
#  'previou': 63,
#  'complement': 9,
#  'earlier': 35,
#  'gap': 13,
#  'prior': 18,
#  '1966': 23,
#  'bold': 2,
#  'sdi': 38,
#  'descript': 102,
#  'luhn': 6,
#  '1958': 10,
#  '1961b': 1,
#  'post': 19,
#  'boom': 2,
#  'began': 18,
#  'lose': 3,
#  'ground': 9,
#  'popular': 9,
#  'therefor': 66,
#  'interpret': 41,
#  'implement': 42,
#  'evolut': 13,
#  'light': 18,
#  'perform': 137,
#  'compani': 11,
#  'agenc': 22,
#  'societi': 48,
#  'fourteen': 3,
#  'herdan': 1,
#  'tri': 36,
#  'give': 66,
#  'statist': 102,
#  'properti': 42,
#  'common': 44,
#  'thread': 6,
#  'multifari': 1,
#  'embodi': 3,
#  'scatter': 21,
#  'linguist': 27,
#  'philosoph': 13,
#  'mathematician': 7,
#  'engin': 68,
#  'idiom': 1,
#  'belong': 11,
#  'quantit': 41,
#  'peculiar': 5,
#  'convent': 37,
#  'put': 34,
#  'differ': 197,
#  'latter': 32,
#  'compri': 9,
#  'paramet': 27,
#  'appli': 104,
#  'econom': 73,
#  'demographi': 1,
#  'former': 17,
#  'characteri': 2,
#  'adumbr': 1,
#  'author': 155,
#  'choic': 32,
#  'chanc': 7,
#  'taken': 47,
#  'shape': 10,
#  'shall': 18,
#  'foundat': 19,
#  'laid': 5,
#  'truli': 3,
#  'sensibl': 4,
#  'langu': 1,
#  'parol': 1,
#  'dichotomi': 1,
#  'sampl': 57,
#  'jewett': 1,
#  'charl': 7,
#  'coffin': 1,
#  'american': 73,
#  '1841': 1,
#  '1868': 2,
#  'harri': 6,
#  'mark': 16,
#  'begin': 37,
#  'associ': 105,
#  'scene': 7,
#  'dynam': 19,
#  'figur': 34,
#  'melvil': 1,
#  'ammi': 1,
#  'cutter': 5,
#  'extrem': 9,
#  'era': 6,
#  'quarter': 13,
#  'centuri': 29,
#  'prece': 6,
#  'philadelphia': 4,
#  'charact': 57,
#  'influenc': 52,
#  'america': 7,
#  'ignor': 12,
#  'nineteenth': 3,
#  'risk': 3,
#  'misinterpret': 1,
#  'pivot': 2,
#  'reapprai': 3,
#  'seem': 73,
#  'appropri': 56,
#  'aggress': 2,
#  'lorenz': 2,
#  'vertebr': 1,
#  'point': 113,
#  'total': 71,
#  'predat': 1,
#  'biolog': 28,
#  'necess': 13,
#  'defenc': 1,
#  'territori': 2,
#  'corner': 2,
#  'anim': 4,
#  'mix': 2,
#  'innat': 2,
#  'drive': 4,
#  'thu': 61,
#  'lead': 45,
#  'reduct': 17,
#  'intraspecif': 1,
#  'damag': 1,
#  'fiercer': 1,
#  'wolv': 1,
#  'escap': 1,
#  'pack': 2,
#  'virtual': 10,
#  'imposs': 4,
#  'co': 38,
#  'fight': 3,
#  'surviv': 10,
#  'wherea': 11,
#  'proverbi': 1,
#  'peac': 3,
#  'dove': 1,
#  'prevent': 14,
#  'violent': 1,
#  'often': 59,
#  'fatal': 1,
#  'attack': 4,
#  'weaker': 2,
#  'mate': 1,
#  'human': 65,
#  'speci': 7,
#  'cultur': 23,
#  'darwinian': 1,
#  'strict': 4,
#  'canal': 1,
#  'man': 33,
#  'innum': 3,
#  'adapt': 22,
#  'ritual': 2,
#  'behavior': 52,
#  'analog': 11,
#  'homolog': 1,
#  'event': 12,
#  'fascin': 2,
#  'master': 18,
#  'manpow': 13,
#  'asheim': 2,
#  'offici': 9,
#  'statement': 33,
#  'offic': 34,
#  'explor': 45,
#  'eventu': 14,
#  'assumpt': 24,
#  'occup': 4,
#  'broader': 11,
#  'supervi': 4,
#  'requir': 151,
#  'complet': 78,
#  'encompass': 5,
#  'engag': 19,
#  'mainten': 17,
#  'norm': 7,
#  'defin': 97,
#  'pre': 13,
#  'posit': 47,
#  'pilot': 17,
#  'braden': 1,
#  'undertaken': 26,
#  'high': 54,
#  'uncertainti': 7,
#  'among': 99,
#  'regard': 48,
#  'extent': 29,
#  'miss': 12,
#  'gave': 8,
#  'ohio': 9,
#  'concret': 4,
#  'indic': 119,
#  'loss': 15,
#  'greatest': 19,
#  'convey': 9,
#  'voic': 5,
#  'complaint': 1,
#  'tend': 24,
#  'forc': 34,
#  'cuadra': 9,
#  'think': 28,
#  'fores': 2,
#  'move': 11,
#  '2000': 5,
#  'anyth': 4,
#  'tomorrow': 2,
#  'algebra': 6,
#  'maltsev': 1,
#  'far': 52,
#  'back': 18,
#  '1920': 2,
#  'forti': 10,
#  'overwhelm': 7,
#  'algebraist': 1,
#  'investig': 120,
#  'ring': 12,
#  'lattic': 1,
#  'theoret': 64,
#  'arbitrari': 7,
#  'due': 18,
#  'birkhoff': 1,
#  '1935': 2,
#  'tarski': 1,
#  'formul': 43,
#  'equip': 33,
#  'contrast': 18,
#  'abund': 4,
#  'apparatu': 3,
#  'logic': 50,
#  'fruit': 8,
#  'classic': 7,
#  'discov': 23,
#  '1936': 2,
#  'next': 15,
#  'twenti': 22,
#  'five': 52,
#  'gradual': 11,
#  'becam': 20,
#  'intim': 4,
#  'despit': 10,
#  'speak': 12,
#  'singl': 57,
#  'formal': 57,
#  'predic': 4,
#  'calculu': 2,
#  'border': 3,
#  'doyl': 4,
#  'exploit': 16,
#  'word': 99,
#  'occurr': 13,
#  'retriev': 296,
#  'mental': 7,
#  ...}

# %%
total_vocab_size = len(DF)
total_vocab_size
# Out:
# 7132

# %%
total_vocab = [x for x in DF]
N=len(total_vocab)
N
# Out:
# 7132

# %%
def doc_freq(word):
    c = 0
    try:
        c = DF[word]
    except:
        pass
    return c

# %%
doc = 0
N=len(tokens_set)
tf_idf = {}

for i in range(len(tokens_set)):
    if(i>0):
        tokens = tokens_set[str(i)]
    
    counter = Counter(tokens)
    words_count = len(tokens)
    
    for token in np.unique(tokens):
        
        tf = counter[token]/words_count
        df = doc_freq(token)
        idf = np.log((N+1)/(df+1))
        
        tf_idf[doc,token] = tf*idf
    doc += 1

print("tf-idf done")
# Out:
# tf-idf done

# %%
tf_idf
# Out:
# {(0, '100'): 0.07993644825190063,
#  (0, '15'): 0.08325138564815435,
#  (0, '150'): 0.10728331001146925,
#  (0, '250000'): 0.10728331001146925,
#  (0, 'author'): 0.040673098263657496,
#  (0, 'averag'): 0.06635073185498752,
#  (0, 'certif'): 0.11251389314695617,
#  (0, 'chemic'): 0.15202182225929642,
#  (0, 'chemistri'): 0.1356919400095013,
#  (0, 'chernyi'): 0.09710847750355248,
#  (0, 'compound'): 0.06784597000475065,
#  (0, 'document'): 0.09586076314032414,
#  (0, 'etc'): 0.06784597000475065,
#  (0, 'increa'): 0.048758295013865596,
#  (0, 'inform'): 0.02884082079632775,
#  (0, 'integr'): 0.06136097102404642,
#  (0, 'journal'): 0.04212842022135816,
#  (0, 'last'): 0.05866242547644145,
#  (0, 'literatur'): 0.034258164179607635,
#  (0, 'modern'): 0.0654181265024866,
#  (0, 'monograph'): 0.07126510148662228,
#  (0, 'new'): 0.03291659745125798,
#  (0, 'number'): 0.035530138517915096,
#  (0, 'paper'): 0.030766636948161095,
#  (0, 'patent'): 0.08325138564815435,
#  (0, 'present'): 0.027667005617560997,
#  (0, 'public'): 0.03737759627083841,
#  (0, 'publish'): 0.08998880205011935,
#  (0, 'relat'): 0.03385320716853266,
#  (0, 'report'): 0.03747508614613632,
#  (0, 'scientif'): 0.10180044068064074,
#  (0, 'specif'): 0.04590368139914442,
#  (0, 'system'): 0.018923084477620665,
#  (0, 'technic'): 0.08769742140180174,
#  (0, 'technolog'): 0.09372168037957691,
#  (0, 'thousand'): 0.08325138564815435,
#  (0, 'throughout'): 0.07126510148662228,
#  (0, 'time'): 0.034340249276962664,
#  (0, 'twenti'): 0.07547967628766454,
#  (0, 'world'): 0.1089606171128112,
#  (0, 'year'): 0.10180044068064074,
#  (1, '18'): 0.09773120232856183,
#  (1, '1876'): 0.11132232351601175,
#  (1, '1971'): 0.07754258630540187,
#  (1, 'abroad'): 0.10774739102985577,
#  (1, 'appear'): 0.055313103786198345,
#  (1, 'attempt'): 0.04805087264312199,
#  (1, 'biographi'): 0.11569768726727075,
#  (1, 'briefli'): 0.07316722255414286,
#  (1, 'classif'): 0.10287989480935812,
#  (1, 'comaromi'): 0.12928880845472068,
#  (1, 'continu'): 0.05985823347359686,
#  (1, 'countri'): 0.06738683941256159,
#  (1, 'ddc'): 0.21549478205971154,
#  (1, 'decim'): 0.17465345363507778,
#  (1, 'describ'): 0.032962242067739254,
#  (1, 'detail'): 0.05219418820522409,
#  (1, 'dewey'): 0.27340112247855536,
#  (1, 'edit'): 0.2729579546651278,
#  (1, 'eighteenth'): 0.12928880845472068,
#  (1, 'first'): 0.0829957810475509,
#  (1, 'full'): 0.06959229006798688,
#  (1, 'futur'): 0.05338290628005614,
#  (1, 'growth'): 0.06014448444263907,
#  (1, 'healthi'): 0.12928880845472068,
#  (1, 'histori'): 0.13006213718425794,
#  (1, 'howev'): 0.05036034393050206,
#  (1, 'librarianship'): 0.066173596202403,
#  (1, 'life'): 0.07054895995366202,
#  (1, 'long'): 0.0665697277184328,
#  (1, 'need'): 0.03445975145567208,
#  (1, 'never'): 0.08851544489237094,
#  (1, 'present'): 0.02983696684246774,
#  (1, 'provid'): 0.03445975145567208,
#  (1, 'publish'): 0.04852337365447612,
#  (1, 'spite'): 0.10210656607982085,
#  (1, 'spur'): 0.11569768726727075,
#  (1, 'stori'): 0.11132232351601175,
#  (1, 'studi'): 0.02730340348011468,
#  (1, 'system'): 0.020407247966061505,
#  (1, 'told'): 0.11132232351601175,
#  (1, 'work'): 0.03438209652986626,
#  (2, '104'): 0.07578999116311212,
#  (2, '6300'): 0.07578999116311212,
#  (2, 'account'): 0.03542739991218084,
#  (2, 'act'): 0.0909119977373677,
#  (2, 'also'): 0.022573177386348175,
#  (2, 'analysi'): 0.021401452807693067,
#  (2, 'aspect'): 0.03037339669665893,
#  (2, 'channel'): 0.04932349584134148,
#  (2, 'colleagu'): 0.05427502361251911,
#  (2, 'collect'): 0.023446578615979465,
#  (2, 'contact'): 0.05619518550519918,
#  (2, 'current'): 0.026087316953284773,
#  (2, 'desk'): 0.06316226370715683,
#  (2, 'document'): 0.040401087913546574,
#  (2, 'doubt'): 0.05427502361251911,
#  (2, 'even'): 0.03203524990138431,
#  (2, 'handbook'): 0.05619518550519918,
#  (2, 'inform'): 0.06381445980796657,
#  (2, 'kingdom'): 0.05619518550519918,
#  (2, 'less'): 0.03542739991218084,
#  (2, 'librari'): 0.08883752804598777,
#  (2, 'made'): 0.02218724295492744,
#  (2, 'major'): 0.026632909335341366,
#  (2, 'one'): 0.03338082010777228,
#  (2, 'oral'): 0.06525791378524827,
#  (2, 'organ'): 0.024590596953301683,
#  (2, 'outsid'): 0.04932349584134148,
#  (2, 'particularli'): 0.03950263000046714,
#  (2, 'pattern'): 0.032557805925255076,
#  (2, 'peopl'): 0.037695899155381934,
#  (2, 'period'): 0.029419409115383436,
#  (2, 'person'): 0.10526792783287724,
#  (2, 'proport'): 0.0885721656842656,
#  (2, 'rare'): 0.051888364247251934,
#  (2, 'rather'): 0.03368008718461043,
#  (2, 'receiv'): 0.038791418463477625,
#  (2, 'regular'): 0.046307814640565714,
#  (2, 'reli'): 0.05850174522315495,
#  (2, 'report'): 0.023691146414224113,
#  (2, 'restrict'): 0.046307814640565714,
#  (2, 'scienc'): 0.018665700363387973,
#  (2, 'situat'): 0.03577573726270187,
#  (2, 'slater'): 0.06316226370715683,
#  (2, 'still'): 0.043567458049243904,
#  (2, 'take'): 0.07085479982436169,
#  (2, 'technic'): 0.11088179717469186,
#  (2, 'technolog'): 0.02962466908549845,
#  (2, 'transfer'): 0.1771443313685312,
#  (2, 'unit'): 0.031413787587932854,
#  (2, 'use'): 0.054802522533119194,
#  (2, 'user'): 0.041909071418967575,
#  (2, 'visit'): 0.05850174522315495,
#  (2, 'way'): 0.02679367073734987,
#  (2, 'whole'): 0.0400024588733377,
#  (2, 'wider'): 0.05053453625120155,
#  (3, 'along'): 0.05799520940430663,
#  (3, 'bibliograph'): 0.13589499209877276,
#  (3, 'certain'): 0.042806504536628376,
#  (3, 'claim'): 0.0626243874386923,
#  (3, 'contain'): 0.0915632449723759,
#  (3, 'control'): 0.2888897737748002,
#  (3, 'deal'): 0.04245112172030422,
#  (3, 'discuss'): 0.025592871336909476,
#  (3, 'el'): 0.07971591436858785,
#  (3, 'enter'): 0.06834068971117148,
#  (3, 'essay'): 0.0626243874386923,
#  (3, 'familiar'): 0.06737742820165549,
#  (3, 'form'): 0.09765362408284115,
#  (3, 'great'): 0.04600274316954826,
#  (3, 'inevit'): 0.07167119047705521,
#  (3, 'inform'): 0.03551295098055283,
#  (3, 'kind'): 0.04600274316954826,
#  (3, 'knowledg'): 0.23837942672833687,
#  (3, 'mankind'): 0.08473788804950148,
#  (3, 'much'): 0.04245112172030422,
#  (3, 'obtain'): 0.04079103761418147,
#  (3, 'organ'): 0.06386214731155959,
#  (3, 'power'): 0.34219168736874384,
#  (3, 'record'): 0.040175471068897156,
#  (3, 'relationship'): 0.04262775541652815,
#  (3, 'satisfactorili'): 0.07971591436858785,
#  (3, 'sen'): 0.053332900672334205,
#  (3, 'simpl'): 0.05007538476158767,
#  (3, 'simpli'): 0.13475485640331097,
#  (3, 'slogan'): 0.09841386912225006,
#  (3, 'stock'): 0.07047652319834571,
#  (3, 'storeh'): 0.09236215109078492,
#  (3, 'stori'): 0.08473788804950148,
#  (3, 'two'): 0.027400566540074608,
#  (3, 'way'): 0.0347917814052155,
#  (3, 'wilson'): 0.08473788804950148,
#  (3, 'write'): 0.22277781195589766,
#  (3, 'written'): 0.050672479308060785,
#  (4, '1960'): 0.07207384678450059,
#  (4, '267'): 0.09673085328902965,
#  (4, 'academ'): 0.0917455751481495,
#  (4, 'also'): 0.03219453168216871,
#  (4, 'although'): 0.052612114226966884,
#  (4, 'analysi'): 0.030523383512611423,
#  (4, 'aspect'): 0.04331943463293979,
#  (4, 'attitud'): 0.06425541937318403,
#  (4, 'basic'): 0.03953572276310735,
#  (4, 'best'): 0.05633981655804329,
#  (4, 'buckland'): 0.08755682397861289,
#  (4, 'chang'): 0.08249809138639458,
#  (4, 'committ'): 0.06316211815189432,
#  (9, 'benefici'): 0.05550623174265298,
#  (9, 'brow'): 0.10789830833728054,
#  (9, 'citizen'): 0.05260035222293802,
#  (9, 'classif'): 0.02649936684483467,
#  (9, 'colleg'): 0.033312044092792176,
#  (9, 'compar'): 0.02467362954840514,
#  (9, 'concept'): 0.045192331404063896,
#  (9, 'confirm'): 0.05260035222293802,
#  (9, 'consid'): 0.018941720807026868,
#  (9, 'current'): 0.022925217928644197,
#  (9, 'data'): 0.015823885203467555,
#  (9, 'definit'): 0.033126699257759885,
#  (9, 'democrat'): 0.0596018388952607,
#  (9, 'direct'): 0.06226633923959058,
#  (9, 'documentari'): 0.10520070444587604,
#  (9, 'educ'): 0.027820978975731755,
#  (9, 'establish'): 0.026404520982715087,
#  (9, 'evid'): 0.03634340361249256,
#  (9, 'exhaust'): 0.04498649563327761,
#  (9, 'find'): 0.02558874970347813,
#  (9, 'follow'): 0.02678936791435418,
#  (9, 'gather'): 0.03828655404327495,
#  (9, 'gener'): 0.014997555922966027,
#  (9, 'greatli'): 0.041933153493146975,
#  (9, 'guidanc'): 0.051410624590045265,
#  (9, 'held'): 0.042852060343709863,
#  (9, 'hyman'): 0.06660332556758339,
#  (9, 'idea'): 0.03224779645988484,
#  (9, 'includ'): 0.021787653503309357,
#  (9, 'indulg'): 0.06250771841497565,
#  (9, 'instrument'): 0.042852060343709863,
#  (9, 'intellectu'): 0.039946180823994905,
#  (9, 'interest'): 0.024056582154669395,
#  (9, 'larg'): 0.020657872693849062,
#  (9, 'left'): 0.0462507698045302,
#  (9, 'less'): 0.03113316961979529,
#  (9, 'librari'): 0.019517335707073074,
#  (9, 'locat'): 0.03828655404327495,
#  (9, 'meant'): 0.05550623174265298,
#  (9, 'method'): 0.01716795710455,
#  (9, 'need'): 0.017751993174134104,
#  (9, 'object'): 0.02659511173326441,
#  (9, 'open'): 0.0462507698045302,
#  (9, 'opinion'): 0.04031353076511486,
#  (9, 'organ'): 0.021609918534719663,
#  (9, 'polit'): 0.04559886555061534,
#  (9, 'princip'): 0.03891807280066216,
#  (9, 'problem'): 0.015530135614570164,
#  (9, 'profess'): 0.026987433281913536,
#  (9, 'promi'): 0.04498649563327761,
#  (9, 'questionnair'): 0.0374076512453999,
#  (9, 'reader'): 0.027500285053362255,
#  (9, 'realiz'): 0.0462507698045302,
#  (9, 'rel'): 0.02815218930727712,
#  (9, 'research'): 0.042196169014722694,
#  (9, 'resist'): 0.05550623174265298,
#  (9, 'scholar'): 0.04498649563327761,
#  (9, 'self'): 0.12327274505704541,
#  (9, 'shelf'): 0.14308869861482312,
#  (9, 'social'): 0.024515798054434622,
#  (9, 'studi'): 0.042196169014722694,
#  (9, 'survey'): 0.025079347141590335,
#  (9, 'tradit'): 0.03294469415167223,
#  (9, 'unresolv'): 0.06250771841497565,
#  (9, 'untutor'): 0.06660332556758339,
#  (9, 'use'): 0.01605326417636825,
#  (9, 'user'): 0.018414591987122118,
#  (9, 'valuabl'): 0.041503258398007614,
#  (9, 'vari'): 0.03859737887829266,
#  (9, 'work'): 0.017711989121446257,
#  (10, '48'): 0.06238943405842417,
#  (16, 'area'): 0.017573304498504378,
#  (16, 'argument'): 0.03247688985259654,
#  (16, 'articl'): 0.01729549992204553,
#  (16, 'attent'): 0.022282170285786145,
#  (16, 'beyond'): 0.03162952988384558,
#  (16, 'bibliographi'): 0.07158096039277506,
#  (16, 'biographi'): 0.04245023058007776,
#  (16, 'book'): 0.022971467013332938,
#  (16, 'card'): 0.02399735750481491,
#  (16, 'case'): 0.02080882918761339,
#  (16, 'catalog'): 0.018607165798261032,
#  (16, 'catalogu'): 0.026067012702309735,
#  (16, 'central'): 0.025037510230074674,
#  (16, 'chang'): 0.018102099189100967,
#  (16, 'chapter'): 0.02399735750481491,
#  (16, 'class'): 0.02399735750481491,
#  (16, 'classif'): 0.07549459906873762,
#  (16, 'comprehen'): 0.02519918545203193,
#  (16, 'concept'): 0.01609367197482851,
#  (16, 'congress'): 0.05453768129905352,
#  (16, 'consid'): 0.013490865898529927,
#  (16, 'copi'): 0.05742502943519958,
#  (16, 'cost'): 0.01632803291320702,
#  (16, 'criteria'): 0.024573204322610134,
#  (16, 'deal'): 0.020462051476693405,
#  (16, 'decid'): 0.02898402786855552,
#  (16, 'deepli'): 0.04245023058007776,
#  (16, 'delv'): 0.04743690094381838,
#  (16, 'describ'): 0.012094060039242462,
#  (16, 'design'): 0.014488322684798223,
#  (16, 'detail'): 0.019150385600477906,
#  (16, 'devot'): 0.027054071130464305,
#  (16, 'effect'): 0.029502653941305763,
#  (16, 'effici'): 0.020720555140190264,
#  (16, 'enclo'): 0.04743690094381838,
#  (16, 'entir'): 0.02726884064952676,
#  ...}

# %% [markdown]
# ## cosine similarilty

# %%
def cosine_sim(a, b):
    cos_sim = np.dot(a, b)/(np.linalg.norm(a)*np.linalg.norm(b))
    return cos_sim

# %%
D = np.zeros((N, total_vocab_size))   #total_vocab_size is the length of DF
for i in tf_idf:
    try:
        ind = total_vocab.index(i[1])
        D[i[0]][ind] = tf_idf[i]
    except:
        pass

# %%
def gen_vector(tokens):

    Q = np.zeros((len(total_vocab)))
    
    counter = Counter(tokens)
    words_count = len(tokens)

    query_weights = {}
    
    for token in np.unique(tokens):
        
        tf = counter[token]/words_count
        df = doc_freq(token)
        idf = math.log((N+1)/(df+1))

        try:
            ind = total_vocab.index(token)
            Q[ind] = tf*idf
        except:
            pass
    return Q

# %%
def cosine_similarity(k, query):
    
    preprocessed_query = preprocess(query)
    tokens = word_tokenize(str(preprocessed_query))
    
    #print("\nQuery:", query)
    
    d_cosines = []
    
    query_vector = gen_vector(tokens)
    
    for d in D:
        d_cosines.append(cosine_sim(query_vector, d))
        
    out = np.array(d_cosines).argsort()[-k:][::-1]
    
    
    #print("Most similar Dpocuments-IDs : ")
    
    #print(out)
    
    return out

# %%
Q = cosine_similarity(5,qry_set["3"])

print('Related documents to given query :\n \"', qry_set["3"] , '" \n' )
Q
# Out:
# Related documents to given query :
#  " What is information science?  Give definitions where possible. "
# array([ 469,  445, 1181, 1179,  540], dtype=int64)

# %% [markdown]
# ### Reading ground truth

# %%
rel_set = {}
with open('IR Project/Datasets.REL') as f:
    for l in f.readlines():
        qry_id = l.lstrip(" ").strip("\n").split("\t")[0].split(" ")[0]
        doc_id = int(l.lstrip(" ").strip("\n").split("\t")[0].split(" ")[-1])
        if qry_id in rel_set:
            rel_set[qry_id].append(doc_id)
        else:
            rel_set[qry_id] = []
            rel_set[qry_id].append(doc_id) 
    
    
print(rel_set["3"]) # note that the dictionary indexes are strings, not numbers.
# Out:
# [60, 85, 118, 123, 126, 131, 133, 137, 138, 160, 346, 359, 363, 372, 412, 445, 454, 461, 463, 469, 532, 539, 540, 553, 554, 555, 585, 590, 599, 640, 660, 664, 803, 901, 909, 911, 1030, 1053, 1077, 1179, 1181, 1190, 1191, 1326]

# %% [markdown]
# ### Precision and recall, Accuracy and Measure

# %%
precision_list=[]
recall_list=[]

# %%
precision_list=[]
recall_list=[]
accuracy_list=[]

for i in range(1,len(doc_set)):
    try:
        result_from_cosine=cosine_similarity(6 , qry_set[str(i)]).tolist()
        result_from_ground_truth=rel_set[str(i)]
        
        true_Positive=len(set(result_from_cosine) & set(result_from_ground_truth)) #set(a) & set(b) gives us intersection between a and b
        false_Positive=len(np.setdiff1d(result_from_cosine , result_from_ground_truth))
        false_Negative=len(np.setdiff1d(result_from_ground_truth , result_from_cosine))
        true_negative= ( len(doc_set) -  (true_Positive + false_Negative + false_Positive) )
        #print("true psotive",true_Positive)
        #print("false negative",false_Negative)
        
        try:
            precission= (true_Positive) / ( true_Positive + false_Positive )
            recall= (true_Positive) / (true_Positive + false_Negative)
            
            accuracy= ( true_negative + true_Positive ) / (  true_negative + true_Positive + false_Negative +false_Positive)
           
        except ZeroDivisionError:
            pass

        precision_list.append(precission)
        recall_list.append(recall)
        accuracy_list.append(accuracy)
        
        
        
    except KeyError:
        pass

# %%
average_precision=sum(precision_list)

# %%
average_recall=sum(recall_list)

# %%
Accuracy= sum(accuracy_list)

# %%
F_Measure = (2 * average_precision * average_recall) / (average_precision + average_recall)

# %%
print("Average Precision is : ", average_precision)
print("Average Recall is : ", average_recall)
print("F-score is : " ,F_Measure)
print("Accuracy : " ,Accuracy)
# Out:
# Average Precision is :  35.99999999999999
# Average Recall is :  11.822298142574425
# F-score is :  17.799342552037704
# Accuracy :  73.85068493150679

# %% [markdown]
# ## Enter a Query, Get your Result
# ### Simple User Interface

# %%
query=input("Enter your query here : ")

Q=cosine_similarity(10,query)

print("\n\nEntered Query is : " , query)
print("\n\nRelated Documents IDs are : ", Q)
print("\nDo you want to retrive the document ? \n press Y to see all related docs \n Press S to see a single document with given id \n Press N to exit ")

entered_option=input()
    
if entered_option == "Y":

    print("\n\n*** You are in All Document Retriveal Mood ***\n\n")

    for i in range(len(Q)):
            print("\n\nDoc-Id :", Q[i] , "\n\t" ,doc_set[str(Q[i])])
           
elif entered_option == "S":
    print("Enter your desired document ID : ")
    doc_id=input()
    print("Doc-Id : ", doc_id, "\n\t" ,doc_set[doc_id])
        

else:
    print("Thank you for using our Information System")
    print("Hassan Ashiq & Usman Ali Abbasi")
# Out:
# Enter your query here : 469
# C:\Users\Evil\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
# Entered Query is :  469
#
#
# Related Documents IDs are :  [1459  478  480  481  482  483  484  485  486  487]
#
# Do you want to retrive the document ?
#  press Y to see all related docs
#  Press S to see a single document with given id
#  Press N to exit
# N
# Thank you for using our Information System
# Hassan Ashiq & Usman Ali Abbasi

# %%
qry_set["3"]
# Out:
# 'What is information science?  Give definitions where possible.'

# %% [markdown]
#  ## IR Semester Project
#  ### NUST
# - #### Submitted by : Hassan Ashiq BESE 23 C
# - ###### Link to my GitHub Repository <a href="https://github.com/hassanashiqasse/PCA">Click Here</a>
